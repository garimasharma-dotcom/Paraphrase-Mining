# %%
! pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (2.21.0)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tf-keras) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.2.6)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras) (0.47.0)
# Requirement already satisfied: rich in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (15.0.0)
# Requirement already satisfied: namex in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.2)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer,util
from sentence_transformers.util import paraphrase_mining
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
s1 = "The is on the mat"
s2 = "A cat is sitting on the mat"
emb1 = model.encode(s1)
emb2 = model.encode(s2)
sim_core = util.cos_sim(emb1,emb2)

# %%
sentences = [
    "The cat sits outside",
    "A man is playing guitar",
    "I love pasta",
    "The new movie is awesome",
    "The cat plays in the garden",
    "A woman watches TV",
    "The new movie is so great",
    "Do you like pizza?",
    "She enjoys reading books",
    "He is walking his dog",
    "The weather is nice today",
    "Let's go to the beach",
    "I need a cup of coffee",
    "They are planning a trip",
    "She cooks delicious meals",
    "I am learning to play the piano",
    "He works at a tech company",
    "This book is very interesting",
    "The sun is shining brightly",
    "It's raining outside",
    "The children are playing soccer",
    "He is fixing the car",
    "She writes beautiful poetry",
    "The flowers are blooming",
    "I enjoy hiking in the mountains",
    "He is swimming in the pool",
    "We are watching a comedy show",
    "The dog is barking loudly",
    "She is painting a landscape",
    "He likes to play video games",
    "I am studying for my exams",
    "They are building a new house",
    "The coffee shop is busy",
    "He listens to classical music",
    "She is designing a website",
    "I bought a new laptop",
    "They are baking cookies",
    "The bird sings in the morning",
    "He loves going to concerts",
    "She practices yoga every day",
    "The phone is ringing",
    "I need to finish this project",
    "The restaurant has great food",
    "He collects rare coins",
    "She enjoys watching documentaries",
    "They are exploring the city",
    "The laptop is charging",
    "He is training for a marathon",
    "I meditate every morning",
    "The bakery sells fresh bread",
    "She is learning French"
]

# %%
paraphrases = paraphrase_mining(model,sentences)
paraphrases[0:16]
# Out:
# [[0.8939036726951599, 3, 6],
#  [0.6787886023521423, 0, 4],
#  [0.6313819885253906, 8, 44],
#  [0.5843967199325562, 13, 45],
#  [0.5794311761856079, 33, 38],
#  [0.5284280180931091, 12, 32],
#  [0.5188641548156738, 29, 38],
#  [0.5187947154045105, 35, 46],
#  [0.5095499157905579, 2, 7],
#  [0.5038481950759888, 8, 50],
#  [0.5013787746429443, 14, 42],
#  [0.48317259550094604, 29, 33],
#  [0.48140883445739746, 15, 30],
#  [0.4788626730442047, 22, 28],
#  [0.47513923048973083, 10, 18],
#  [0.472940057516098, 5, 44]]

# %%
for i in paraphrases[0:20]:
    score,i,j = i
    print("{} \t\t\t\t {} \t\t\t score : {:.4f}".format(sentences[i], sentences[j], score))
# Out:
# The new movie is awesome 				 The new movie is so great 			 score : 0.8939
# The cat sits outside 				 The cat plays in the garden 			 score : 0.6788
# She enjoys reading books 				 She enjoys watching documentaries 			 score : 0.6314
# They are planning a trip 				 They are exploring the city 			 score : 0.5844
# He listens to classical music 				 He loves going to concerts 			 score : 0.5794
# I need a cup of coffee 				 The coffee shop is busy 			 score : 0.5284
# He likes to play video games 				 He loves going to concerts 			 score : 0.5189
# I bought a new laptop 				 The laptop is charging 			 score : 0.5188
# I love pasta 				 Do you like pizza? 			 score : 0.5095
# She enjoys reading books 				 She is learning French 			 score : 0.5038
# She cooks delicious meals 				 The restaurant has great food 			 score : 0.5014
# He likes to play video games 				 He listens to classical music 			 score : 0.4832
# I am learning to play the piano 				 I am studying for my exams 			 score : 0.4814
# She writes beautiful poetry 				 She is painting a landscape 			 score : 0.4789
# The weather is nice today 				 The sun is shining brightly 			 score : 0.4751
# A woman watches TV 				 She enjoys watching documentaries 			 score : 0.4729
# She cooks delicious meals 				 She writes beautiful poetry 			 score : 0.4727
# She is painting a landscape 				 She is designing a website 			 score : 0.4725
# They are baking cookies 				 The bakery sells fresh bread 			 score : 0.4682
# She enjoys reading books 				 She writes beautiful poetry 			 score : 0.4526

# %%
model = SentenceTransformer("distiluse-base-multilingual-cased-v1")
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
corpus1 = ["The stock market saw a big drop"
           "Shares declined sharply due to economic news."
           "Money gets money in stock",
           "It may rain today"]
corpus_emb = model.encode(corpus1)

# %%
#compute paiwaise cosine similarity
cos_similarity = util.pytorch_cos_sim(corpus_emb,corpus_emb)
avg_sim = cos_similarity.mean(dim=1)
outlier_index = avg_sim.argmin().item()
outlier_index
print(f"Outlier sentence : {corpus1[outlier_index]} (AVG similarity :{avg_sim[outlier_index]})")
# Out:
# Outlier sentence : The stock market saw a big dropShares declined sharply due to economic news.Money gets money in stock (AVG similarity :0.5372306108474731)

# %%
corpus1 = ["The cat slept on the sofa.",
           "A kitten was resting on the couch.",
           "The feline took a nap indoors.",
           "The airplane landed safely at the airport."]
corpus_emb = model.encode(corpus1)

# %%
#compute paiwaise cosine similarity
cos_similarity = util.pytorch_cos_sim(corpus_emb,corpus_emb)
avg_sim = cos_similarity.mean(dim=1)
outlier_index = avg_sim.argmin().item()
outlier_index
print(f"Outlier sentence : {corpus1[outlier_index]} (AVG similarity :{avg_sim[outlier_index]})")
# Out:
# Outlier sentence : The airplane landed safely at the airport. (AVG similarity :0.40740108489990234)

# %%
i
